# %%
import pandas as pd

# %%
comb_data = pd.read_csv("wrangled data_comb_data2.csv")

# %%
comb_data.head(10)
# Out:
#                                         comment_text  toxic  severe_toxic  \
# 0  explanation\nwhy the edits made under my usern...  False         False
# 1  daww he matches this background colour im seem...  False         False
# 2  hey man im really not trying to edit war its j...  False         False
# 3  more\ni cant make any real suggestions on impr...  False         False
# 4  you sir are my hero any chance you remember wh...  False         False
# 5  congratulations from me as well use the tools ...  False         False
# 6  your vandalism to the matt shirvington article...  False         False
# 7  sorry if the word nonsense was offensive to yo...  False         False
# 8  alignment on this subject and which are contra...  False         False
# 9  fair use rationale for imagewonjujpg\n\nthanks...  False         False
#
#    obscene  threat  insult  identity_hate
# 0    False   False   False          False
# 1    False   False   False          False
# ...

# %%
comb_data['comment_text'] = comb_data['comment_text'].str.replace("\n", " ")
comb_data['comment_text'] = comb_data['comment_text'].str.strip()

# %%
comb_data.head(10)
# Out:
#                                         comment_text  toxic  severe_toxic  \
# 0  explanation why the edits made under my userna...  False         False
# 1  daww he matches this background colour im seem...  False         False
# 2  hey man im really not trying to edit war its j...  False         False
# 3  more i cant make any real suggestions on impro...  False         False
# 4  you sir are my hero any chance you remember wh...  False         False
# 5  congratulations from me as well use the tools ...  False         False
# 6  your vandalism to the matt shirvington article...  False         False
# 7  sorry if the word nonsense was offensive to yo...  False         False
# 8  alignment on this subject and which are contra...  False         False
# 9  fair use rationale for imagewonjujpg  thanks f...  False         False
#
#    obscene  threat  insult  identity_hate
# 0    False   False   False          False
# 1    False   False   False          False
# ...

# %%
comb_data.to_csv('tcc_clean.csv', index=False)
